# %%
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Experiment 1

# %%
from pycaret.regression import *

# %%
s = setup(data, target = 'charges', session_id = 123)

# %%
lr = create_model('lr')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     4165.9659  3.330203e+07  5770.7909  0.8011  0.4683  0.4153
# 1     4503.7366  4.374648e+07  6614.1122  0.7456  0.5633  0.4217
# 2     3880.5528  3.179514e+07  5638.7179  0.5974  0.7645  0.4396
# 3     3747.6457  2.680530e+07  5177.3833  0.7762  0.5015  0.5175
# 4     4471.0419  4.341053e+07  6588.6670  0.6771  0.5224  0.3767
# 5     4182.7551  3.616633e+07  6013.8450  0.7674  0.7416  0.4320
# 6     4081.1022  3.919259e+07  6260.3984  0.7333  0.6434  0.4241
# 7     4928.1534  4.641504e+07  6812.8581  0.7448  0.5887  0.4137
# 8     4609.3147  4.037035e+07  6353.7670  0.7392  0.5686  0.5111
# 9     4665.8647  4.259679e+07  6526.6220  0.7256  0.8131  0.4802
# Mean  4323.6133  3.838006e+07  6175.7162  0.7308  0.6175  0.4432
# SD     353.5472  5.908389e+06   490.4977  0.0543  0.1126  0.0431

# %%
plot_model(lr)

# %% [markdown]
# # Experiment 2

# %%
s2 = setup(data, target = 'charges', session_id = 123,
           normalize = True,
           polynomial_features = True, trigonometry_features = True, feature_interaction=True, 
           bin_numeric_features= ['age', 'bmi'])
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow15_col1 {
#             background-color:  lightgreen;
#         }    #T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow25_col1 {
#             background-color:  lightgreen;
#         }    #T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow32_col1 {
#             background-color:  lightgreen;
#         }    #T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow34_col1 {
#             background-color:  lightgreen;
#         }    #T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow39_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow3_col1" class="data row3 col1" >(1338, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow5_col1" class="data row5 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow6_col1" class="data row6 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow10_col1" class="data row10 col1" >(1338, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow11_col1" class="data row11 col1" >(936, 62)</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow12_col1" class="data row12 col1" >(402, 62)</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676eblevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_517aa1ae_bc49_11ea_a36d_f4b7e2f676ebrow17_col0" class="data row17 col0" >Transformation </td>

# %%
s2[0].columns
# Out:
# Index(['bmi_Power2', 'age_Power2', 'sex_female', 'children_0', 'children_1',
#        'children_2', 'children_3', 'children_4', 'children_5', 'smoker_no',
#        'region_northeast', 'region_northwest', 'region_southeast',
#        'region_southwest', 'age_0.0', 'age_1.0', 'age_10.0', 'age_11.0',
#        'age_2.0', 'age_3.0', 'age_4.0', 'age_5.0', 'age_6.0', 'age_7.0',
#        'age_8.0', 'age_9.0', 'bmi_0.0', 'bmi_1.0', 'bmi_10.0', 'bmi_11.0',
#        'bmi_2.0', 'bmi_3.0', 'bmi_4.0', 'bmi_5.0', 'bmi_6.0', 'bmi_7.0',
#        'bmi_8.0', 'bmi_9.0', 'age_Power2_multiply_bmi_7.0',
#        'smoker_no_multiply_age_Power2', 'region_northeast_multiply_bmi_Power2',
#        'age_Power2_multiply_smoker_no', 'children_0_multiply_age_Power2',
#        'sex_female_multiply_age_Power2', 'sex_female_multiply_bmi_Power2',
#        'bmi_Power2_multiply_smoker_no', 'age_6.0_multiply_age_Power2',
#        'bmi_Power2_multiply_children_0', 'age_0.0_multiply_smoker_no',
#        'smoker_no_multiply_bmi_Power2', 'age_Power2_multiply_bmi_Power2',
#        'children_1_multiply_bmi_Power2', 'bmi_Power2_multiply_age_Power2',
#        'smoker_no_multiply_sex_female', 'bmi_Power2_multiply_children_2',
#        'children_0_multiply_bmi_Power2', 'age_Power2_multiply_children_0',
#        'region_southwest_multiply_smoker_no',
#        'region_northwest_multiply_bmi_Power2',
#        'region_southeast_multiply_bmi_Power2',
#        'region_southeast_multiply_smoker_no', 'smoker_no_multiply_children_0'],
#       dtype='object')

# %%
lr = create_model('lr')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     3001.4888  2.075270e+07  4555.5133  0.8760  0.4135  0.3483
# 1     3581.3331  3.300788e+07  5745.2483  0.8081  0.4692  0.3499
# 2     3105.2226  2.410703e+07  4909.8907  0.6948  0.5420  0.4107
# 3     3261.8674  2.757907e+07  5251.5779  0.7697  0.5622  0.4882
# 4     3326.1075  2.920562e+07  5404.2223  0.7828  0.4775  0.3137
# 5     3214.5964  2.437705e+07  4937.3120  0.8432  0.3688  0.2858
# 6     2980.1199  2.606423e+07  5105.3142  0.8226  0.3919  0.3208
# 7     3512.4964  3.043716e+07  5516.9882  0.8326  0.5338  0.3129
# 8     3179.3947  2.286867e+07  4782.1199  0.8523  0.4041  0.3493
# 9     3285.4181  2.910614e+07  5395.0106  0.8125  0.5179  0.3735
# Mean  3244.8045  2.675055e+07  5160.3197  0.8095  0.4681  0.3553
# SD     186.3855  3.593658e+06   348.7906  0.0486  0.0663  0.0554

# %%
plot_model(lr)

# %%
save_model(lr, 'deployment_28042020')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
deployment_28042020 = load_model('deployment_28042020')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
deployment_28042020
# Out:
# [Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        ml_usecase='regression',
#                                        numerical_features=[], target='charges',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  numeric_strategy='mean',
#                                  target_variable=None)),
#                  ('new_levels1',
#                   New_Catagorical_Levels...
#                  ('dummy', Dummify(target='charges')),
#                  ('fix_perfect', Remove_100(target='charges')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', Empty()), ('fix_multi', Empty()),
#                  ('dfs',
#                   DFS_Classic(interactions=['multiply'], ml_usecase='regression',
#                               random_state=123, subclass='binary',
#                               target='charges',
#                               top_features_to_pick_percentage=None)),
#                  ('pca', Empty())],
#           verbose=False),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  None]

# %%
import requests
url = 'https://pycaret-insurance.herokuapp.com/predict_api'
pred = requests.post(url,json={'age':55, 'sex':'male', 'bmi':59, 'children':1, 'smoker':'male', 'region':'northwest'})
print(pred.json())
# Out:
# 75714.0
